# %%
import numpy as np, matplotlib.pyplot as plt, pandas as pd

# %%
df = pd.read_csv('data/exercise.csv')
df = df.head(500)
df[['Weight', 'Duration']]
# Out:
#      Weight  Duration
# 0      94.0      29.0
# 1      60.0      14.0
# 2      79.0       5.0
# 3      71.0      13.0
# 4      58.0      10.0
# ..      ...       ...
# 495    57.0      14.0
# 496    58.0      25.0
# 497    89.0       6.0
# 498    70.0      13.0
# 499    70.0       2.0
#
# [500 rows x 2 columns]

# %%
plt.scatter([1,2,3], [14,5,6])

# %%
plt.grid(True)

plt.ylabel("Duration")
plt.xlabel("Weight")
plt.scatter(df['Weight'], df['Duration'], marker='<', color='k')

# %%
df.plot()
# Out:
# <AxesSubplot: >
